# %%
import random
from enum import StrEnum
from typing import Self
from rich import print as rprint


class Names(StrEnum):
    JOHN = f"[dark_turquoise]Джон Леннон[/dark_turquoise]"
    PAUL = f"[navy_blue]Пол Маккартни[/navy_blue]"
    GEORGE = f"[bright_magenta]Джордж Харрисон[/bright_magenta]"
    RINGO = f"[deep_pink4]Ринго Старр[/deep_pink4]"


class Beetle:
    health_points: int
    name: Names
    max_power: int
    min_power: int
    max_health: int

    def __init__(
        self,
        health_points: int = 100,
        name: Names = Names.JOHN,
        max_power: int = 10,
        min_power: int = 5,
        max_health: int = 100
    ) -> None:
        self.health_points = health_points
        self.name = name
        self.max_power = max_power
        self.min_power = min_power
        self.max_health = max_health

    def __eq__(self, other: Self) -> bool:
        return self.health_points == other.health_points

    def __lt__(self, other: Self) -> bool:
        return self.health_points < other.health_points

    def __le__(self, other: Self) -> bool:
        return self.health_points <= other.health_points

    def __str__(self) -> str:
        return f'Жук(имя="{self.name}", здоровье={self.health_points!r}, сила={self.min_power!r}-{self.max_power!r})'

    def attack_style(self) -> str:
        if self.name is Names.JOHN:
            return "в [yellow italic]манере Джонни[/yellow italic]"
        elif self.name is Names.PAUL:
            return "в [green italic]манере Маккартни[/green italic]"
        elif self.name is Names.GEORGE:
            return "в [dark_goldenrod italic]манере Харрисона[/dark_goldenrod italic]"
        elif self.name is Names.RINGO:
            return "в [pale_turquoise1 italic]манере Ринго[/pale_turquoise1 italic]"

    def attack(self, other: Self) -> None:
        damage = random.randint(self.min_power, self.max_power)
        rprint(f"{self.name} бьет {other.name} {self.attack_style()} и наносит [bold red]{damage}[/bold red] урона")
        other.health_points -= damage


class BeetlesArmy:
    beetles_list: list[Beetle]
    beetles_name: Names
    beetles_max_health: int
    beetles_max_power: int
    beetles_min_power: int

    def __init__(
        self,
        beetles_name: Names,
        beetles_army_size: int = 20,
        beetles_max_health: int = 100,
        beetles_max_power: int = 10,
        beetles_min_power: int = 5
    ):
        self.beetles_list = []
        self.beetles_name = beetles_name
        self.beetles_max_health = beetles_max_health
        self.beetles_max_power = beetles_max_power
        self.beetles_min_power = beetles_min_power

        for _ in range(beetles_army_size):
            beetle = Beetle(
                health_points=random.randint(1, self.beetles_max_health),
                name=self.beetles_name,
                max_power=self.beetles_max_power,
                min_power=self.beetles_min_power,
                max_health=self.beetles_max_health
            )
            self.beetles_list.append(beetle)

    def __len__(self) -> int:
        return len(self.beetles_list)

    def show_army(self):
        for beetle in self.beetles_list:
            rprint(beetle)

    def compare_with(self, other: 'BeetlesArmy') -> str:
        total_health_self = sum(b.health_points for b in self.beetles_list)
        total_health_other = sum(b.health_points for b in other.beetles_list)
        
        if total_health_self > total_health_other:
            return f"Армия {self.beetles_name} сильнее по общему здоровью"
        elif total_health_self < total_health_other:
            return f"Армия {other.beetles_name} сильнее по общему здоровью"
        else:
            return f"Обе армии равны по общему здоровью"


def begin_game():
    rprint("Готовы начать игру?")
    army_count = int(input("Введите количество армий [2-4]:"))

    if army_count < 2 or army_count > 4:
        rprint("Неверное количество. Нужно от 2 до 4.")
    else:
        create_armies(army_count)


def create_armies(army_count):
    chosen_names = []
    while len(chosen_names) < army_count:
        rprint(f"Выберите имя для армии {len(chosen_names) + 1} ([dark_turquoise]JOHN[/dark_turquoise], [navy_blue]PAUL[/navy_blue], [bright_magenta]GEORGE[/bright_magenta], [deep_pink4]RINGO[/deep_pink4]): ")
        name_choice = input()

        if name_choice.upper() not in ["JOHN", "PAUL", "GEORGE", "RINGO"]:
            rprint("Неверное имя. Выберите из списка.")
        else:
            chosen_names.append(name_choice)

    armies = []
    for i, name in enumerate(chosen_names):
        name_enum = Names[name.upper()]

        size = int(input(f"Сколько жуков в армии {i + 1}? "))

        max_hp = int(input(f"Максимальное здоровье жуков в армии {i + 1}: "))

        max_damage = int(input(f"Максимальная сила атаки в армии {i + 1}: "))
        
        min_damage = int(input(f"Минимальная сила атаки в армии {i + 1}: "))
        
        if min_damage > max_damage:
            rprint("Минимальная сила не может быть больше максимальной. Установлено равным 1.")
            min_damage = 1

        army = BeetlesArmy(
            beetles_name=name_enum,
            beetles_army_size=size,
            beetles_max_health=max_hp,
            beetles_max_power=max_damage,
            beetles_min_power=min_damage
        )

        armies.append(army)

    rprint(f"\nСоздано {len(armies)} армий!")
    
    # Сравнение армий
    for i in range(len(armies)):
        for j in range(i+1, len(armies)):
            comparison_result = armies[i].compare_with(armies[j])
            rprint(comparison_result)

    answer = input("\nНачинаем? [Да/Нет]")

    if answer.upper() == "ДА":
        start_battle(armies)
    elif answer.upper() == "НЕТ":
        rprint("Как хотите.")
    else:
        rprint("Не понял.")


def start_battle(armies):
    round_num = 1
    while len(armies) > 1:
        rprint(f"[bold blue]=== Раунд {round_num} ===[/bold blue]")
        round_num += 1
        
        army1 = armies[0]
        army2 = armies[1]

        if len(army1) > 0 and len(army2) > 0:
            rprint(f"\n{army1.beetles_name} [bold yellow]атакует[/bold yellow] {army2.beetles_name}!")
            
            army1.beetles_list[0].attack(army2.beetles_list[0])

            if army2.beetles_list[0].health_points <= 0:
                rprint(f"{army2.beetles_list[0].name} [bold red3]погиб[/bold red3]!")
                
                # Увеличиваем здоровье убийцы
                if (army1.beetles_list[0].health_points + 10) <= army1.beetles_max_health:
                    army1.beetles_list[0].health_points += 10
                    rprint(f"{army1.beetles_list[0].name} восстановил здоровье до {army1.beetles_list[0].health_points}")
                
                army2.beetles_list.pop(0)

            if len(army2) > 0:
                rprint(f"\n{army2.beetles_name} [bold yellow]атакует[/bold yellow] {army1.beetles_name}!")
                
                army2.beetles_list[0].attack(army1.beetles_list[0])

                if army1.beetles_list[0].health_points <= 0:
                    rprint(f"{army1.beetles_list[0].name} [bold red3]погиб[/bold red3]!")
                    
                    # Увеличиваем здоровье убийцы
                    if (army2.beetles_list[0].health_points + 10) <= army2.beetles_max_health:
                        army2.beetles_list[0].health_points += 10
                        rprint(f"{army2.beetles_list[0].name} восстановил здоровье до {army2.beetles_list[0].health_points}")
                    
                    army1.beetles_list.pop(0)

            rprint(f"\nАрмия {army1.beetles_name}: осталось [bold green]{len(army1)}[/bold green] жуков")
            rprint(f"Армия {army2.beetles_name}: осталось [bold green]{len(army2)}[/bold green] жуков")
            rprint()

        else:
            if len(army1) == 0:
                rprint(f"Армия {army1.beetles_name} [bold red3]уничтожена[/bold red3]!")
                rprint()
                armies.pop(0)
            else:
                rprint(f"Армия {army2.beetles_name} [bold red3]уничтожена[/bold red3]!")
                rprint()
                armies.pop(1)

    rprint(f"Армия {armies[0].beetles_name} [bold green1]одержала победу[/bold green1]!")
    rprint()


begin_game()
# Out:
# Готовы начать игру?
# Выберите имя для армии 1 (JOHN, PAUL, GEORGE, RINGO):
# Выберите имя для армии 2 (JOHN, PAUL, GEORGE, RINGO):
# Выберите имя для армии 3 (JOHN, PAUL, GEORGE, RINGO):
# Выберите имя для армии 4 (JOHN, PAUL, GEORGE, RINGO):
# Неверное имя. Выберите из списка.
# Выберите имя для армии 4 (JOHN, PAUL, GEORGE, RINGO):
# Минимальная сила не может быть больше максимальной. Установлено равным 1.
# Минимальная сила не может быть больше максимальной. Установлено равным 1.
# Создано 4 армий!
# Армия Ринго Старр сильнее по общему здоровью
# Армия Ринго Старр сильнее по общему здоровью
# Армия Ринго Старр сильнее по общему здоровью
# Армия Джордж Харрисон сильнее по общему здоровью
# Армия Джордж Харрисон сильнее по общему здоровью
# Обе армии равны по общему здоровью
# === Раунд 1 ===
# Ринго Старр атакует Джордж Харрисон!
# Ринго Старр бьет Джордж Харрисон в манере Ринго и наносит 24 урона
# Джордж Харрисон погиб!
# Джордж Харрисон атакует Ринго Старр!
# Джордж Харрисон бьет Ринго Старр в манере Харрисона и наносит 45 урона
# Ринго Старр погиб!
# Джордж Харрисон восстановил здоровье до 11
# Армия Ринго Старр: осталось 19 жуков
# Армия Джордж Харрисон: осталось 39 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 2 ===
# Ринго Старр атакует Джордж Харрисон!
# Ринго Старр бьет Джордж Харрисон в манере Ринго и наносит 27 урона
# Джордж Харрисон погиб!
# Ринго Старр восстановил здоровье до 19
# Джордж Харрисон атакует Ринго Старр!
# Джордж Харрисон бьет Ринго Старр в манере Харрисона и наносит 45 урона
# Ринго Старр погиб!
# Джордж Харрисон восстановил здоровье до 15
# Армия Ринго Старр: осталось 18 жуков
# Армия Джордж Харрисон: осталось 38 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 3 ===
# Ринго Старр атакует Джордж Харрисон!
# Ринго Старр бьет Джордж Харрисон в манере Ринго и наносит 30 урона
# Джордж Харрисон погиб!
# Джордж Харрисон атакует Ринго Старр!
# Джордж Харрисон бьет Ринго Старр в манере Харрисона и наносит 45 урона
# Ринго Старр погиб!
# Армия Ринго Старр: осталось 17 жуков
# Армия Джордж Харрисон: осталось 37 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 4 ===
# Ринго Старр атакует Джордж Харрисон!
# Ринго Старр бьет Джордж Харрисон в манере Ринго и наносит 38 урона
# Джордж Харрисон погиб!
# Джордж Харрисон атакует Ринго Старр!
# Джордж Харрисон бьет Ринго Старр в манере Харрисона и наносит 45 урона
# Ринго Старр погиб!
# Армия Ринго Старр: осталось 16 жуков
# Армия Джордж Харрисон: осталось 36 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 5 ===
# Ринго Старр атакует Джордж Харрисон!
# Ринго Старр бьет Джордж Харрисон в манере Ринго и наносит 32 урона
# Джордж Харрисон погиб!
# Ринго Старр восстановил здоровье до 29
# Джордж Харрисон атакует Ринго Старр!
# Джордж Харрисон бьет Ринго Старр в манере Харрисона и наносит 45 урона
# Ринго Старр погиб!
# Армия Ринго Старр: осталось 15 жуков
# Армия Джордж Харрисон: осталось 35 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 6 ===
# Ринго Старр атакует Джордж Харрисон!
# Ринго Старр бьет Джордж Харрисон в манере Ринго и наносит 31 урона
# Джордж Харрисон погиб!
# Ринго Старр восстановил здоровье до 30
# Джордж Харрисон атакует Ринго Старр!
# Джордж Харрисон бьет Ринго Старр в манере Харрисона и наносит 45 урона
# Ринго Старр погиб!
# Армия Ринго Старр: осталось 14 жуков
# Армия Джордж Харрисон: осталось 34 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 7 ===
# Ринго Старр атакует Джордж Харрисон!
# Ринго Старр бьет Джордж Харрисон в манере Ринго и наносит 23 урона
# Джордж Харрисон погиб!
# Джордж Харрисон атакует Ринго Старр!
# Джордж Харрисон бьет Ринго Старр в манере Харрисона и наносит 45 урона
# Ринго Старр погиб!
# Джордж Харрисон восстановил здоровье до 13
# Армия Ринго Старр: осталось 13 жуков
# Армия Джордж Харрисон: осталось 33 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 8 ===
# Ринго Старр атакует Джордж Харрисон!
# Ринго Старр бьет Джордж Харрисон в манере Ринго и наносит 38 урона
# Джордж Харрисон погиб!
# Джордж Харрисон атакует Ринго Старр!
# Джордж Харрисон бьет Ринго Старр в манере Харрисона и наносит 45 урона
# Ринго Старр погиб!
# Армия Ринго Старр: осталось 12 жуков
# Армия Джордж Харрисон: осталось 32 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 9 ===
# Ринго Старр атакует Джордж Харрисон!
# Ринго Старр бьет Джордж Харрисон в манере Ринго и наносит 37 урона
# Джордж Харрисон погиб!
# Ринго Старр восстановил здоровье до 15
# Джордж Харрисон атакует Ринго Старр!
# Джордж Харрисон бьет Ринго Старр в манере Харрисона и наносит 45 урона
# Ринго Старр погиб!
# Армия Ринго Старр: осталось 11 жуков
# Армия Джордж Харрисон: осталось 31 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 10 ===
# Ринго Старр атакует Джордж Харрисон!
# Ринго Старр бьет Джордж Харрисон в манере Ринго и наносит 31 урона
# Джордж Харрисон погиб!
# Ринго Старр восстановил здоровье до 18
# Джордж Харрисон атакует Ринго Старр!
# Джордж Харрисон бьет Ринго Старр в манере Харрисона и наносит 45 урона
# Ринго Старр погиб!
# Армия Ринго Старр: осталось 10 жуков
# Армия Джордж Харрисон: осталось 30 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 11 ===
# Ринго Старр атакует Джордж Харрисон!
# Ринго Старр бьет Джордж Харрисон в манере Ринго и наносит 32 урона
# Джордж Харрисон погиб!
# Джордж Харрисон атакует Ринго Старр!
# Джордж Харрисон бьет Ринго Старр в манере Харрисона и наносит 45 урона
# Ринго Старр погиб!
# Армия Ринго Старр: осталось 9 жуков
# Армия Джордж Харрисон: осталось 29 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 12 ===
# Ринго Старр атакует Джордж Харрисон!
# Ринго Старр бьет Джордж Харрисон в манере Ринго и наносит 27 урона
# Джордж Харрисон погиб!
# Джордж Харрисон атакует Ринго Старр!
# Джордж Харрисон бьет Ринго Старр в манере Харрисона и наносит 45 урона
# Ринго Старр погиб!
# Армия Ринго Старр: осталось 8 жуков
# Армия Джордж Харрисон: осталось 28 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 13 ===
# Ринго Старр атакует Джордж Харрисон!
# Ринго Старр бьет Джордж Харрисон в манере Ринго и наносит 28 урона
# Джордж Харрисон погиб!
# Ринго Старр восстановил здоровье до 12
# Джордж Харрисон атакует Ринго Старр!
# Джордж Харрисон бьет Ринго Старр в манере Харрисона и наносит 45 урона
# Ринго Старр погиб!
# Армия Ринго Старр: осталось 7 жуков
# Армия Джордж Харрисон: осталось 27 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 14 ===
# Ринго Старр атакует Джордж Харрисон!
# Ринго Старр бьет Джордж Харрисон в манере Ринго и наносит 39 урона
# Джордж Харрисон погиб!
# Ринго Старр восстановил здоровье до 18
# Джордж Харрисон атакует Ринго Старр!
# Джордж Харрисон бьет Ринго Старр в манере Харрисона и наносит 45 урона
# Ринго Старр погиб!
# Армия Ринго Старр: осталось 6 жуков
# Армия Джордж Харрисон: осталось 26 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 15 ===
# Ринго Старр атакует Джордж Харрисон!
# Ринго Старр бьет Джордж Харрисон в манере Ринго и наносит 35 урона
# Джордж Харрисон погиб!
# Джордж Харрисон атакует Ринго Старр!
# Джордж Харрисон бьет Ринго Старр в манере Харрисона и наносит 45 урона
# Ринго Старр погиб!
# Джордж Харрисон восстановил здоровье до 14
# Армия Ринго Старр: осталось 5 жуков
# Армия Джордж Харрисон: осталось 25 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 16 ===
# Ринго Старр атакует Джордж Харрисон!
# Ринго Старр бьет Джордж Харрисон в манере Ринго и наносит 23 урона
# Джордж Харрисон погиб!
# Джордж Харрисон атакует Ринго Старр!
# Джордж Харрисон бьет Ринго Старр в манере Харрисона и наносит 45 урона
# Ринго Старр погиб!
# Армия Ринго Старр: осталось 4 жуков
# Армия Джордж Харрисон: осталось 24 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 17 ===
# Ринго Старр атакует Джордж Харрисон!
# Ринго Старр бьет Джордж Харрисон в манере Ринго и наносит 37 урона
# Джордж Харрисон погиб!
# Ринго Старр восстановил здоровье до 29
# Джордж Харрисон атакует Ринго Старр!
# Джордж Харрисон бьет Ринго Старр в манере Харрисона и наносит 45 урона
# Ринго Старр погиб!
# Армия Ринго Старр: осталось 3 жуков
# Армия Джордж Харрисон: осталось 23 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 18 ===
# Ринго Старр атакует Джордж Харрисон!
# Ринго Старр бьет Джордж Харрисон в манере Ринго и наносит 33 урона
# Джордж Харрисон погиб!
# Ринго Старр восстановил здоровье до 21
# Джордж Харрисон атакует Ринго Старр!
# Джордж Харрисон бьет Ринго Старр в манере Харрисона и наносит 45 урона
# Ринго Старр погиб!
# Армия Ринго Старр: осталось 2 жуков
# Армия Джордж Харрисон: осталось 22 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 19 ===
# Ринго Старр атакует Джордж Харрисон!
# Ринго Старр бьет Джордж Харрисон в манере Ринго и наносит 33 урона
# Джордж Харрисон погиб!
# Джордж Харрисон атакует Ринго Старр!
# Джордж Харрисон бьет Ринго Старр в манере Харрисона и наносит 45 урона
# Ринго Старр погиб!
# Джордж Харрисон восстановил здоровье до 15
# Армия Ринго Старр: осталось 1 жуков
# Армия Джордж Харрисон: осталось 21 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 20 ===
# Ринго Старр атакует Джордж Харрисон!
# Ринго Старр бьет Джордж Харрисон в манере Ринго и наносит 33 урона
# Джордж Харрисон погиб!
# Джордж Харрисон атакует Ринго Старр!
# Джордж Харрисон бьет Ринго Старр в манере Харрисона и наносит 45 урона
# Ринго Старр погиб!
# Джордж Харрисон восстановил здоровье до 11
# Армия Ринго Старр: осталось 0 жуков
# Армия Джордж Харрисон: осталось 20 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 21 ===
# Армия Ринго Старр уничтожена!
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 22 ===
# Джордж Харрисон атакует Пол Маккартни!
# Джордж Харрисон бьет Пол Маккартни в манере Харрисона и наносит 45 урона
# Пол Маккартни погиб!
# Пол Маккартни атакует Джордж Харрисон!
# Пол Маккартни бьет Джордж Харрисон в манере Маккартни и наносит 1 урона
# Армия Джордж Харрисон: осталось 20 жуков
# Армия Пол Маккартни: осталось 31 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 23 ===
# Джордж Харрисон атакует Пол Маккартни!
# Джордж Харрисон бьет Пол Маккартни в манере Харрисона и наносит 45 урона
# Пол Маккартни погиб!
# Пол Маккартни атакует Джордж Харрисон!
# Пол Маккартни бьет Джордж Харрисон в манере Маккартни и наносит 4 урона
# Армия Джордж Харрисон: осталось 20 жуков
# Армия Пол Маккартни: осталось 30 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 24 ===
# Джордж Харрисон атакует Пол Маккартни!
# Джордж Харрисон бьет Пол Маккартни в манере Харрисона и наносит 45 урона
# Пол Маккартни погиб!
# Пол Маккартни атакует Джордж Харрисон!
# Пол Маккартни бьет Джордж Харрисон в манере Маккартни и наносит 4 урона
# Армия Джордж Харрисон: осталось 20 жуков
# Армия Пол Маккартни: осталось 29 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 25 ===
# Джордж Харрисон атакует Пол Маккартни!
# Джордж Харрисон бьет Пол Маккартни в манере Харрисона и наносит 45 урона
# Пол Маккартни погиб!
# Джордж Харрисон восстановил здоровье до 12
# Пол Маккартни атакует Джордж Харрисон!
# Пол Маккартни бьет Джордж Харрисон в манере Маккартни и наносит 3 урона
# Армия Джордж Харрисон: осталось 20 жуков
# Армия Пол Маккартни: осталось 28 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 26 ===
# Джордж Харрисон атакует Пол Маккартни!
# Джордж Харрисон бьет Пол Маккартни в манере Харрисона и наносит 45 урона
# Пол Маккартни погиб!
# Пол Маккартни атакует Джордж Харрисон!
# Пол Маккартни бьет Джордж Харрисон в манере Маккартни и наносит 4 урона
# Армия Джордж Харрисон: осталось 20 жуков
# Армия Пол Маккартни: осталось 27 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 27 ===
# Джордж Харрисон атакует Пол Маккартни!
# Джордж Харрисон бьет Пол Маккартни в манере Харрисона и наносит 45 урона
# Пол Маккартни погиб!
# Джордж Харрисон восстановил здоровье до 15
# Пол Маккартни атакует Джордж Харрисон!
# Пол Маккартни бьет Джордж Харрисон в манере Маккартни и наносит 1 урона
# Армия Джордж Харрисон: осталось 20 жуков
# Армия Пол Маккартни: осталось 26 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 28 ===
# Джордж Харрисон атакует Пол Маккартни!
# Джордж Харрисон бьет Пол Маккартни в манере Харрисона и наносит 45 урона
# Пол Маккартни погиб!
# Пол Маккартни атакует Джордж Харрисон!
# Пол Маккартни бьет Джордж Харрисон в манере Маккартни и наносит 4 урона
# Армия Джордж Харрисон: осталось 20 жуков
# Армия Пол Маккартни: осталось 25 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 29 ===
# Джордж Харрисон атакует Пол Маккартни!
# Джордж Харрисон бьет Пол Маккартни в манере Харрисона и наносит 45 урона
# Пол Маккартни погиб!
# Пол Маккартни атакует Джордж Харрисон!
# Пол Маккартни бьет Джордж Харрисон в манере Маккартни и наносит 3 урона
# Армия Джордж Харрисон: осталось 20 жуков
# Армия Пол Маккартни: осталось 24 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 30 ===
# Джордж Харрисон атакует Пол Маккартни!
# Джордж Харрисон бьет Пол Маккартни в манере Харрисона и наносит 45 урона
# Пол Маккартни погиб!
# Пол Маккартни атакует Джордж Харрисон!
# Пол Маккартни бьет Джордж Харрисон в манере Маккартни и наносит 1 урона
# Армия Джордж Харрисон: осталось 20 жуков
# Армия Пол Маккартни: осталось 23 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 31 ===
# Джордж Харрисон атакует Пол Маккартни!
# Джордж Харрисон бьет Пол Маккартни в манере Харрисона и наносит 45 урона
# Пол Маккартни погиб!
# Пол Маккартни атакует Джордж Харрисон!
# Пол Маккартни бьет Джордж Харрисон в манере Маккартни и наносит 4 урона
# Армия Джордж Харрисон: осталось 20 жуков
# Армия Пол Маккартни: осталось 22 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 32 ===
# Джордж Харрисон атакует Пол Маккартни!
# Джордж Харрисон бьет Пол Маккартни в манере Харрисона и наносит 45 урона
# Пол Маккартни погиб!
# Джордж Харрисон восстановил здоровье до 12
# Пол Маккартни атакует Джордж Харрисон!
# Пол Маккартни бьет Джордж Харрисон в манере Маккартни и наносит 4 урона
# Армия Джордж Харрисон: осталось 20 жуков
# Армия Пол Маккартни: осталось 21 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 33 ===
# Джордж Харрисон атакует Пол Маккартни!
# Джордж Харрисон бьет Пол Маккартни в манере Харрисона и наносит 45 урона
# Пол Маккартни погиб!
# Пол Маккартни атакует Джордж Харрисон!
# Пол Маккартни бьет Джордж Харрисон в манере Маккартни и наносит 2 урона
# Армия Джордж Харрисон: осталось 20 жуков
# Армия Пол Маккартни: осталось 20 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 34 ===
# Джордж Харрисон атакует Пол Маккартни!
# Джордж Харрисон бьет Пол Маккартни в манере Харрисона и наносит 45 урона
# Пол Маккартни погиб!
# Пол Маккартни атакует Джордж Харрисон!
# Пол Маккартни бьет Джордж Харрисон в манере Маккартни и наносит 1 урона
# Армия Джордж Харрисон: осталось 20 жуков
# Армия Пол Маккартни: осталось 19 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 35 ===
# Джордж Харрисон атакует Пол Маккартни!
# Джордж Харрисон бьет Пол Маккартни в манере Харрисона и наносит 45 урона
# Пол Маккартни погиб!
# Джордж Харрисон восстановил здоровье до 15
# Пол Маккартни атакует Джордж Харрисон!
# Пол Маккартни бьет Джордж Харрисон в манере Маккартни и наносит 2 урона
# Армия Джордж Харрисон: осталось 20 жуков
# Армия Пол Маккартни: осталось 18 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 36 ===
# Джордж Харрисон атакует Пол Маккартни!
# Джордж Харрисон бьет Пол Маккартни в манере Харрисона и наносит 45 урона
# Пол Маккартни погиб!
# Пол Маккартни атакует Джордж Харрисон!
# Пол Маккартни бьет Джордж Харрисон в манере Маккартни и наносит 3 урона
# Армия Джордж Харрисон: осталось 20 жуков
# Армия Пол Маккартни: осталось 17 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 37 ===
# Джордж Харрисон атакует Пол Маккартни!
# Джордж Харрисон бьет Пол Маккартни в манере Харрисона и наносит 45 урона
# Пол Маккартни погиб!
# Пол Маккартни атакует Джордж Харрисон!
# Пол Маккартни бьет Джордж Харрисон в манере Маккартни и наносит 3 урона
# Армия Джордж Харрисон: осталось 20 жуков
# Армия Пол Маккартни: осталось 16 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 38 ===
# Джордж Харрисон атакует Пол Маккартни!
# Джордж Харрисон бьет Пол Маккартни в манере Харрисона и наносит 45 урона
# Пол Маккартни погиб!
# Пол Маккартни атакует Джордж Харрисон!
# Пол Маккартни бьет Джордж Харрисон в манере Маккартни и наносит 2 урона
# Армия Джордж Харрисон: осталось 20 жуков
# Армия Пол Маккартни: осталось 15 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 39 ===
# Джордж Харрисон атакует Пол Маккартни!
# Джордж Харрисон бьет Пол Маккартни в манере Харрисона и наносит 45 урона
# Пол Маккартни погиб!
# Джордж Харрисон восстановил здоровье до 15
# Пол Маккартни атакует Джордж Харрисон!
# Пол Маккартни бьет Джордж Харрисон в манере Маккартни и наносит 4 урона
# Армия Джордж Харрисон: осталось 20 жуков
# Армия Пол Маккартни: осталось 14 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 40 ===
# Джордж Харрисон атакует Пол Маккартни!
# Джордж Харрисон бьет Пол Маккартни в манере Харрисона и наносит 45 урона
# Пол Маккартни погиб!
# Пол Маккартни атакует Джордж Харрисон!
# Пол Маккартни бьет Джордж Харрисон в манере Маккартни и наносит 1 урона
# Армия Джордж Харрисон: осталось 20 жуков
# Армия Пол Маккартни: осталось 13 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 41 ===
# Джордж Харрисон атакует Пол Маккартни!
# Джордж Харрисон бьет Пол Маккартни в манере Харрисона и наносит 45 урона
# Пол Маккартни погиб!
# Пол Маккартни атакует Джордж Харрисон!
# Пол Маккартни бьет Джордж Харрисон в манере Маккартни и наносит 4 урона
# Армия Джордж Харрисон: осталось 20 жуков
# Армия Пол Маккартни: осталось 12 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 42 ===
# Джордж Харрисон атакует Пол Маккартни!
# Джордж Харрисон бьет Пол Маккартни в манере Харрисона и наносит 45 урона
# Пол Маккартни погиб!
# Пол Маккартни атакует Джордж Харрисон!
# Пол Маккартни бьет Джордж Харрисон в манере Маккартни и наносит 1 урона
# Армия Джордж Харрисон: осталось 20 жуков
# Армия Пол Маккартни: осталось 11 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 43 ===
# Джордж Харрисон атакует Пол Маккартни!
# Джордж Харрисон бьет Пол Маккартни в манере Харрисона и наносит 45 урона
# Пол Маккартни погиб!
# Джордж Харрисон восстановил здоровье до 15
# Пол Маккартни атакует Джордж Харрисон!
# Пол Маккартни бьет Джордж Харрисон в манере Маккартни и наносит 3 урона
# Армия Джордж Харрисон: осталось 20 жуков
# Армия Пол Маккартни: осталось 10 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 44 ===
# Джордж Харрисон атакует Пол Маккартни!
# Джордж Харрисон бьет Пол Маккартни в манере Харрисона и наносит 45 урона
# Пол Маккартни погиб!
# Пол Маккартни атакует Джордж Харрисон!
# Пол Маккартни бьет Джордж Харрисон в манере Маккартни и наносит 1 урона
# Армия Джордж Харрисон: осталось 20 жуков
# Армия Пол Маккартни: осталось 9 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 45 ===
# Джордж Харрисон атакует Пол Маккартни!
# Джордж Харрисон бьет Пол Маккартни в манере Харрисона и наносит 45 урона
# Пол Маккартни погиб!
# Пол Маккартни атакует Джордж Харрисон!
# Пол Маккартни бьет Джордж Харрисон в манере Маккартни и наносит 1 урона
# Армия Джордж Харрисон: осталось 20 жуков
# Армия Пол Маккартни: осталось 8 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 46 ===
# Джордж Харрисон атакует Пол Маккартни!
# Джордж Харрисон бьет Пол Маккартни в манере Харрисона и наносит 45 урона
# Пол Маккартни погиб!
# Пол Маккартни атакует Джордж Харрисон!
# Пол Маккартни бьет Джордж Харрисон в манере Маккартни и наносит 2 урона
# Армия Джордж Харрисон: осталось 20 жуков
# Армия Пол Маккартни: осталось 7 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 47 ===
# Джордж Харрисон атакует Пол Маккартни!
# Джордж Харрисон бьет Пол Маккартни в манере Харрисона и наносит 45 урона
# Пол Маккартни погиб!
# Пол Маккартни атакует Джордж Харрисон!
# Пол Маккартни бьет Джордж Харрисон в манере Маккартни и наносит 2 урона
# Армия Джордж Харрисон: осталось 20 жуков
# Армия Пол Маккартни: осталось 6 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 48 ===
# Джордж Харрисон атакует Пол Маккартни!
# Джордж Харрисон бьет Пол Маккартни в манере Харрисона и наносит 45 урона
# Пол Маккартни погиб!
# Пол Маккартни атакует Джордж Харрисон!
# Пол Маккартни бьет Джордж Харрисон в манере Маккартни и наносит 3 урона
# Армия Джордж Харрисон: осталось 20 жуков
# Армия Пол Маккартни: осталось 5 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 49 ===
# Джордж Харрисон атакует Пол Маккартни!
# Джордж Харрисон бьет Пол Маккартни в манере Харрисона и наносит 45 урона
# Пол Маккартни погиб!
# Джордж Харрисон восстановил здоровье до 13
# Пол Маккартни атакует Джордж Харрисон!
# Пол Маккартни бьет Джордж Харрисон в манере Маккартни и наносит 1 урона
# Армия Джордж Харрисон: осталось 20 жуков
# Армия Пол Маккартни: осталось 4 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 50 ===
# Джордж Харрисон атакует Пол Маккартни!
# Джордж Харрисон бьет Пол Маккартни в манере Харрисона и наносит 45 урона
# Пол Маккартни погиб!
# Пол Маккартни атакует Джордж Харрисон!
# Пол Маккартни бьет Джордж Харрисон в манере Маккартни и наносит 4 урона
# Армия Джордж Харрисон: осталось 20 жуков
# Армия Пол Маккартни: осталось 3 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 51 ===
# Джордж Харрисон атакует Пол Маккартни!
# Джордж Харрисон бьет Пол Маккартни в манере Харрисона и наносит 45 урона
# Пол Маккартни погиб!
# Пол Маккартни атакует Джордж Харрисон!
# Пол Маккартни бьет Джордж Харрисон в манере Маккартни и наносит 2 урона
# Армия Джордж Харрисон: осталось 20 жуков
# Армия Пол Маккартни: осталось 2 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 52 ===
# Джордж Харрисон атакует Пол Маккартни!
# Джордж Харрисон бьет Пол Маккартни в манере Харрисона и наносит 45 урона
# Пол Маккартни погиб!
# Пол Маккартни атакует Джордж Харрисон!
# Пол Маккартни бьет Джордж Харрисон в манере Маккартни и наносит 2 урона
# Армия Джордж Харрисон: осталось 20 жуков
# Армия Пол Маккартни: осталось 1 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 53 ===
# Джордж Харрисон атакует Пол Маккартни!
# Джордж Харрисон бьет Пол Маккартни в манере Харрисона и наносит 45 урона
# Пол Маккартни погиб!
# Джордж Харрисон восстановил здоровье до 14
# Армия Джордж Харрисон: осталось 20 жуков
# Армия Пол Маккартни: осталось 0 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 54 ===
# Армия Пол Маккартни уничтожена!
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 55 ===
# Джордж Харрисон атакует Джон Леннон!
# Джордж Харрисон бьет Джон Леннон в манере Харрисона и наносит 45 урона
# Джон Леннон погиб!
# Джон Леннон атакует Джордж Харрисон!
# Джон Леннон бьет Джордж Харрисон в манере Джонни и наносит 32 урона
# Джордж Харрисон погиб!
# Джон Леннон восстановил здоровье до 32
# Армия Джордж Харрисон: осталось 19 жуков
# Армия Джон Леннон: осталось 11 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 56 ===
# Джордж Харрисон атакует Джон Леннон!
# Джордж Харрисон бьет Джон Леннон в манере Харрисона и наносит 45 урона
# Джон Леннон погиб!
# Джон Леннон атакует Джордж Харрисон!
# Джон Леннон бьет Джордж Харрисон в манере Джонни и наносит 45 урона
# Джордж Харрисон погиб!
# Армия Джордж Харрисон: осталось 18 жуков
# Армия Джон Леннон: осталось 10 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 57 ===
# Джордж Харрисон атакует Джон Леннон!
# Джордж Харрисон бьет Джон Леннон в манере Харрисона и наносит 45 урона
# Джон Леннон погиб!
# Джон Леннон атакует Джордж Харрисон!
# Джон Леннон бьет Джордж Харрисон в манере Джонни и наносит 27 урона
# Джордж Харрисон погиб!
# Джон Леннон восстановил здоровье до 17
# Армия Джордж Харрисон: осталось 17 жуков
# Армия Джон Леннон: осталось 9 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 58 ===
# Джордж Харрисон атакует Джон Леннон!
# Джордж Харрисон бьет Джон Леннон в манере Харрисона и наносит 45 урона
# Джон Леннон погиб!
# Джордж Харрисон восстановил здоровье до 11
# Джон Леннон атакует Джордж Харрисон!
# Джон Леннон бьет Джордж Харрисон в манере Джонни и наносит 23 урона
# Джордж Харрисон погиб!
# Джон Леннон восстановил здоровье до 20
# Армия Джордж Харрисон: осталось 16 жуков
# Армия Джон Леннон: осталось 8 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 59 ===
# Джордж Харрисон атакует Джон Леннон!
# Джордж Харрисон бьет Джон Леннон в манере Харрисона и наносит 45 урона
# Джон Леннон погиб!
# Джордж Харрисон восстановил здоровье до 15
# Джон Леннон атакует Джордж Харрисон!
# Джон Леннон бьет Джордж Харрисон в манере Джонни и наносит 24 урона
# Джордж Харрисон погиб!
# Джон Леннон восстановил здоровье до 29
# Армия Джордж Харрисон: осталось 15 жуков
# Армия Джон Леннон: осталось 7 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 60 ===
# Джордж Харрисон атакует Джон Леннон!
# Джордж Харрисон бьет Джон Леннон в манере Харрисона и наносит 45 урона
# Джон Леннон погиб!
# Джон Леннон атакует Джордж Харрисон!
# Джон Леннон бьет Джордж Харрисон в манере Джонни и наносит 9 урона
# Армия Джордж Харрисон: осталось 15 жуков
# Армия Джон Леннон: осталось 6 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 61 ===
# Джордж Харрисон атакует Джон Леннон!
# Джордж Харрисон бьет Джон Леннон в манере Харрисона и наносит 45 урона
# Джон Леннон погиб!
# Джордж Харрисон восстановил здоровье до 15
# Джон Леннон атакует Джордж Харрисон!
# Джон Леннон бьет Джордж Харрисон в манере Джонни и наносит 13 урона
# Армия Джордж Харрисон: осталось 15 жуков
# Армия Джон Леннон: осталось 5 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 62 ===
# Джордж Харрисон атакует Джон Леннон!
# Джордж Харрисон бьет Джон Леннон в манере Харрисона и наносит 45 урона
# Джон Леннон погиб!
# Джордж Харрисон восстановил здоровье до 12
# Джон Леннон атакует Джордж Харрисон!
# Джон Леннон бьет Джордж Харрисон в манере Джонни и наносит 36 урона
# Джордж Харрисон погиб!
# Джон Леннон восстановил здоровье до 34
# Армия Джордж Харрисон: осталось 14 жуков
# Армия Джон Леннон: осталось 4 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 63 ===
# Джордж Харрисон атакует Джон Леннон!
# Джордж Харрисон бьет Джон Леннон в манере Харрисона и наносит 45 урона
# Джон Леннон погиб!
# Джон Леннон атакует Джордж Харрисон!
# Джон Леннон бьет Джордж Харрисон в манере Джонни и наносит 26 урона
# Джордж Харрисон погиб!
# Джон Леннон восстановил здоровье до 32
# Армия Джордж Харрисон: осталось 13 жуков
# Армия Джон Леннон: осталось 3 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 64 ===
# Джордж Харрисон атакует Джон Леннон!
# Джордж Харрисон бьет Джон Леннон в манере Харрисона и наносит 45 урона
# Джон Леннон погиб!
# Джон Леннон атакует Джордж Харрисон!
# Джон Леннон бьет Джордж Харрисон в манере Джонни и наносит 7 урона
# Армия Джордж Харрисон: осталось 13 жуков
# Армия Джон Леннон: осталось 2 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 65 ===
# Джордж Харрисон атакует Джон Леннон!
# Джордж Харрисон бьет Джон Леннон в манере Харрисона и наносит 45 урона
# Джон Леннон погиб!
# Джордж Харрисон восстановил здоровье до 12
# Джон Леннон атакует Джордж Харрисон!
# Джон Леннон бьет Джордж Харрисон в манере Джонни и наносит 25 урона
# Джордж Харрисон погиб!
# Джон Леннон восстановил здоровье до 21
# Армия Джордж Харрисон: осталось 12 жуков
# Армия Джон Леннон: осталось 1 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 66 ===
# Джордж Харрисон атакует Джон Леннон!
# Джордж Харрисон бьет Джон Леннон в манере Харрисона и наносит 45 урона
# Джон Леннон погиб!
# Армия Джордж Харрисон: осталось 12 жуков
# Армия Джон Леннон: осталось 0 жуков
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === Раунд 67 ===
# Армия Джон Леннон уничтожена!
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Армия Джордж Харрисон одержала победу!
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
